# %% [markdown]
# ### ベイズ推定を用いた
#
# https://towardsdatascience.com/hands-on-bayesian-statistics-with-python-pymc3-arviz-499db9a59501

# %%
from scipy import stats
import arviz as az
import numpy as np
import matplotlib.pyplot as plt
import pymc3 as pm
import seaborn as sns
import pandas as pd
from theano import shared
from sklearn import preprocessing
from IPython.display import display
import seaborn as sns

print('Running on PyMC3 v{}'.format(pm.__version__))
data = pd.read_csv('renfe_small.csv')
#data.drop('Unnamed: 0', axis = 1, inplace=True)
data = data.sample(frac=0.1, random_state=120)
data.head(3)
# Out:
# /Users/daikionodera/ENV_py3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Running on PyMC3 v3.7
#                insert_date  origin destination           start_date  \
# 14841  2019-04-18 15:20:43  MADRID     SEVILLA  2019-05-18 07:00:00
# 4693   2019-04-24 15:30:31  MADRID   BARCELONA  2019-05-03 18:30:00
# 12425  2019-04-16 03:29:25  MADRID    VALENCIA  2019-05-08 15:10:00
#
#                   end_date train_type  price   train_class   fare
# 14841  2019-05-18 09:55:00    AV City  58.95  Turista Plus  Promo
# 4693   2019-05-03 21:20:00        AVE  98.00    Preferente  Promo
# 12425  2019-05-08 16:52:00        AVE  27.80       Turista  Promo

# %% [markdown]
# ## 欠損値に対する処理
#
# 1. 欠損している列とその割合を確認する。
# あまりに欠損が多ければ、その列は使わない。それ以外はデータの分布を見た上で補間する。

# %%
data.isnull().sum()/len(data)
# Out:
# insert_date    0.000000
# origin         0.000000
# destination    0.000000
# start_date     0.000000
# end_date       0.000000
# train_type     0.000000
# price          0.128682
# train_class    0.005426
# fare           0.005426
# dtype: float64

# %% [markdown]
# price列、train_class列、fare列に欠損があるが、いずれも11%程度であるため、データの分布を見た上で補間する。
# 連続値についてはヒストグラムで、離散値についてはカウントプロットでデータを確認する。

# %%
data[data["price"].notnull()].hist(column="price")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10296d3c8>]],
#       dtype=object)

# %%
data.groupby("fare")["price"].hist(alpha=0.5)
# Out:
# fare
# Adulto ida             AxesSubplot(0.125,0.125;0.775x0.755)
# Flexible               AxesSubplot(0.125,0.125;0.775x0.755)
# Individual-Flexible    AxesSubplot(0.125,0.125;0.775x0.755)
# Promo                  AxesSubplot(0.125,0.125;0.775x0.755)
# Promo +                AxesSubplot(0.125,0.125;0.775x0.755)
# Name: price, dtype: object

# %%
sns.countplot(x="train_class", data=data)

# %%
sns.countplot(x="fare", data=data)

# %%
data['train_class'] = data['train_class'].fillna(data['train_class'].mode().iloc[0])
data['fare'] = data['fare'].fillna(data['fare'].mode().iloc[0])
data['price'] = data.groupby('fare').transform(lambda x: x.fillna(x.mean()))

# %%
az.plot_kde(data['price'].values, rug=True)
plt.yticks([0], alpha=0)
# Out:
# ([<matplotlib.axis.YTick at 0x11bc92940>],
#  <a list of 1 Text yticklabel objects>)

# %%
data["price"].hist()

# %% [markdown]
# ## Model

# %% [markdown]
# yをチケットの価格としてモデルを検討する。
# 誤差構造は正規分布に従うと仮定し、平均は0から300までの値を取り、ばらつきは現段階では前提知識もないため、学習がある程度可能な大きさの10を設定しておく。

# %%
with pm.Model() as model_g:
    μ = pm.Uniform('μ', lower=0, upper=300)
    σ = pm.HalfNormal('σ', sd=10)
    y = pm.Normal('y', mu=μ, sd=σ, observed=data['price'].values)
    trace_g = pm.sample(1000, tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [σ, μ]
# Sampling 2 chains: 100%|██████████| 4000/4000 [00:02<00:00, 1372.28draws/s]

# %%
az.plot_trace(trace_g)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fddf5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d615048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x124d0f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124d342e8>]],
#       dtype=object)

# %% [markdown]
# チェイン数を2つに設定しているため、2つの分布が表示される。
# 2つのチェインで同様の傾向を示していること、中心がはっきりと分かる正規分布になっていることから、$μ$も$σ$も正しそうな値を求めていることが推測される。
# 右の各サンプルの値を見ても、おかしな挙動はしていない。

# %%
az.plot_joint(trace_g, kind='kde', fill_last=False)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x11bd4e320>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11bdaf6a0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11bdce588>)

# %% [markdown]
# 今回設定した二つのパラメータ間に関連があるかどうかを確認したい。
# 上の図からは、特定の関連性は見られないので、$μ$と$σ$はそれぞれ独立で問題が無いだろうと推測される。

# %%
az.summary(trace_g)
# Out:
#      mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# μ  64.240  0.474  63.338   65.075      0.011    0.007    2034.0  2034.0
# σ  24.891  0.345  24.268   25.520      0.008    0.005    2021.0  2021.0
#
#    ess_bulk  ess_tail  r_hat
# μ    2041.0    1298.0    1.0
# σ    2035.0    1463.0    1.0

# %%
az.plot_posterior(trace_g)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c004128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11c376d68>],
#       dtype=object)

# %% [markdown]
# ### Gelman Rubinテストにより、それぞれのパラメータの収束を確認する。
# 1に近い値を取れば、収束しているらしい。
# https://docs.pymc.io/api/diagnostics.html

# %%
pm.gelman_rubin(trace_g)
# Out:
# {'μ': 1.0000214438475072, 'σ': 1.0001610678288142}

# %%
bfmi = pm.bfmi(trace_g)
max_gr = max(np.max(gr_stats) for gr_stats in pm.gelman_rubin(trace_g).values())
(pm.energyplot(trace_g, legend=False, figsize=(6, 4)).set_title("BFMI = {}\nGelman-Rubin = {}".format(bfmi, max_gr)));

# %% [markdown]
# BFMIはBayesian fraction of missing informationの略で、サンプリングする際に小さな局所解にトラップされて探索範囲が狭まっていないかどうかの指標らしく、0.2以下の値をとると、サンプリングがうまくいっていないと見なせるらしい。
# https://docs.pymc.io/api/stats.html
#
# energyplotもそれぞれのチェインでどれくらい広い範囲を探索できたのかを調べるプロットみたい。
# https://docs.pymc.io/api/plots.html

# %%
ppc = pm.sample_posterior_predictive(trace_g, samples=1000, model=model_g)
np.asarray(ppc['y']).shape
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 816.62it/s]
# (1000, 2580)

# %%
_, ax = plt.subplots(figsize=(10, 5))
ax.hist([y.mean() for y in ppc['y']], bins=19, alpha=0.5)
ax.axvline(data.price.mean())
ax.set(title='Posterior predictive of the mean', xlabel='mean(x)', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'),
#  Text(0.5, 0, 'mean(x)'),
#  Text(0.5, 1.0, 'Posterior predictive of the mean')]

# %% [markdown]
# yを求めたい鉄道のチケットの値段として、平均を$μ$、分散を$σ$と仮定した正規分布に従って生成されると考えてきている。
# 事後分布は$P(y) = N(y|μ, σ)$となり、sample_posterior_predictive関数によって実際に事後分布がどのように推定されているのかを確認できる。
# サンプルされたyの平均値が実際のチケットの平均値に一致しているかどうかを確認した。

# %% [markdown]
# ### 次にFareのカテゴリ毎に値段の分布が違うことを考慮する。

# %%
price = data['price'].values
idx = pd.Categorical(data['fare'], categories=data["fare"].unique()).codes
groups = len(np.unique(idx))

# %%
with pm.Model() as comparing_groups:
    μ = pm.Normal('μ', mu=0, sd=10, shape=groups)
    σ = pm.HalfNormal('σ', sd=10, shape=groups)

    y = pm.Normal('y', mu=μ[idx], sd=σ[idx], observed=price)

    trace_groups = pm.sample(5000, tune=5000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [σ, μ]
# Sampling 2 chains: 100%|██████████| 20000/20000 [00:47<00:00, 250.34draws/s]

# %%
flat_fares = az.from_pymc3(trace=trace_groups)
fares_gaussian = az.summary(flat_fares)
fares_gaussian
# Out:
#         mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean   ess_sd  \
# μ[0]  61.956  0.518  61.026   62.944      0.005    0.003   12737.0  12735.0
# μ[1]  81.943  0.947  80.114   83.667      0.009    0.007   10553.0  10515.0
# μ[2]  31.147  0.449  30.294   31.964      0.004    0.003   12835.0  12824.0
# μ[3]  35.866  0.588  34.808   37.005      0.006    0.004   10791.0  10784.0
# μ[4]  10.406  9.917  -8.564   28.751      0.104    0.081    9135.0   7474.0
# σ[0]  21.521  0.372  20.824   22.221      0.003    0.002   13326.0  13300.0
# σ[1]  23.224  0.659  21.978   24.448      0.006    0.004   10972.0  10968.0
# σ[2]   5.854  0.319   5.279    6.463      0.003    0.002   11397.0  11244.0
# σ[3]   4.607  0.423   3.825    5.384      0.004    0.003   11011.0  10649.0
# σ[4]  37.689  5.032  28.452   47.011      0.048    0.034   10893.0  10743.0
#
#       ess_bulk  ess_tail  r_hat
# μ[0]   12729.0    7649.0    1.0
# μ[1]   10653.0    7403.0    1.0
# μ[2]   12847.0    8182.0    1.0
# μ[3]   10801.0    7232.0    1.0
# μ[4]    9161.0    7560.0    1.0
# σ[0]   13366.0    7506.0    1.0
# σ[1]   10945.0    7939.0    1.0
# σ[2]   11581.0    7769.0    1.0
# σ[3]   11532.0    7215.0    1.0
# σ[4]   10897.0    8854.0    1.0

# %%
dist = stats.norm()

_, ax = plt.subplots(5, 2, figsize=(20, 12), constrained_layout=True)

comparisons = [(i, j) for i in range(groups) for j in range(i+1, groups)]
pos = [(k, l) for k in range(5) for l in (0, 1)]

for (i, j), (k, l) in zip(comparisons, pos):
    means_diff = trace_groups['μ'][:, i] - trace_groups['μ'][:, j]
    d_cohen = (means_diff / np.sqrt((trace_groups['σ'][:, i]**2 + trace_groups['σ'][:, j]**2) / 2)).mean()
    ps = dist.cdf(d_cohen/(2**0.5))
    az.plot_posterior(means_diff, ref_val=0, ax=ax[k, l])
    ax[k, l].set_title(f'$\mu_{i}-\mu_{j}$')
    ax[k, l].plot(0, label=f"Cohen's d = {d_cohen:.2f}\nProb sup = {ps:.2f}", alpha=0)
    ax[k, l].legend()

# %% [markdown]
# ### サンプリングによる線形回帰モデルのパラメータ推定

# %%
data["fare"].unique()
# Out:
# array(['Promo', 'Flexible', 'Adulto ida', 'Promo +',
#        'Individual-Flexible'], dtype=object)

# %%
def replace_fare(fare):
    if fare == 'Adulto ida':
        return 1
    elif fare == 'Promo +':
        return 2
    elif fare == 'Promo':
        return 3
    elif fare == 'Flexible':
        return 4
    elif fare == 'Individual-Flexible':
        return 5
    elif fare == 'Mesa':
        return 6

data['fare_encode'] = data['fare'].apply(lambda x: replace_fare(x))

label_encoder = preprocessing.LabelEncoder() 
data['train_type_encode']= label_encoder.fit_transform(data['train_type'])

train_type_names = data.train_type.unique()
train_type_idx = data.train_type_encode.values

n_train_types = len(data.train_type.unique())

data[['train_type', 'price', 'fare_encode']].head()

# %%
with pm.Model() as hierarchical_model:
    # global model parameters
    α_μ_tmp = pm.Normal('α_μ_tmp', mu=0., sd=100)
    α_σ_tmp = pm.HalfNormal('α_σ_tmp', 5.)
    β_μ = pm.Normal('β_μ', mu=0., sd=100)
    β_σ = pm.HalfNormal('β_σ', 5.)

    # train type specific model parameters
    α_tmp = pm.Normal('α_tmp', mu=α_μ_tmp, sd=α_σ_tmp, shape=n_train_types)  
    # Intercept for each train type, distributed around train type mean 
    β = pm.Normal('β', mu=β_μ, sd=β_σ, shape=n_train_types)
    # Model error
    eps = pm.HalfCauchy('eps', 5.)

    fare_est = α_tmp[train_type_idx] + β[train_type_idx]*data.fare_encode.values

    # Data likelihood
    fare_like = pm.Normal('fare_like', mu=fare_est, sd=eps, observed=data.price)
    
with hierarchical_model:
    hierarchical_trace = pm.sample(2000, tune=2000, target_accept=.9)
    
pm.traceplot(hierarchical_trace, var_names=['α_μ_tmp', 'β_μ', 'α_σ_tmp', 'β_σ', 'eps'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-191b46c08194> in <module>
#       7
#       8     # train type specific model parameters
# ----> 9     α_tmp = pm.Normal('α_tmp', mu=α_μ_tmp, sd=α_σ_tmp, shape=n_train_types)
#      10     # Intercept for each train type, distributed around train type mean
#      11     β = pm.Normal('β', mu=β_μ, sd=β_σ, shape=n_train_types)
#
# NameError: name 'n_train_types' is not defined
